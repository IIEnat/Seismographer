# %%
import pandas as pd
import obspy

# %%
stations = ["2022/Station1/GG.WAR8.centaur-6_1267_20220101_000000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_000000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_010000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_020000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_030000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_040000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_050000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_060000.miniseed",
    "2022/Station1/GG.WAR8.centaur-6_1267_20220101_070000.miniseed"
]


for i in stations:
    station = obspy.read(i)
    trace = station[0]
    trace = trace.slice(starttime = trace.stats.starttime + 10, endtime = trace.stats.starttime + 20)
    trace.plot()
